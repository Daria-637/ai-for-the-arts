# %% [markdown]
# This notebook will show my progress and understanding of Python and GitHub.

# %% [markdown]
# My aim:
# - to learn and understand basic coding
# - to master using GitHub
# - to familiarise myself with programming to open new doors to other coding languages

# %% [markdown]
# Hello, World!
#
# The following code/sentence was created as my first attempt at programming in this course's assignment. This will help me understand how to write and run code in github codespace.

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# GitHub Codespaces is only available for 60 hours per month, and pausing it helps conserve resources. Open your list of code spaces from “My Codespaces” to view your currently active code spaces. If one is active, select the “Pause code space” option to temporarily suspend it. The code space will be saved and can be resumed later from where you left off.

# %% [markdown]
# I struggled a lot with trying to “Commit and Sync” from my Codespace. It took me more than three days to overcome the problem. It works now, but I am still not completely sure how the problem occurred and how I could have fixed it because I was asking my friends for help and eventually ended up re-making the Codespace.

# %% [markdown]
# ### Using Microsoft Copilot with Codespaces

# %% [markdown]
# 1. Basic Math

# %%
a = 1983
b = 932
print("Sum:", a + b)
print("Difference:", a - b)
print("Product:", a * b)
print("Division:", a / b)
# Out:
# Sum: 2915
# Difference: 1051
# Product: 1848156
# Division: 2.1276824034334765

# %% [markdown]
# 2. Functions

# %%
def greet(name):
    print("Hello,", name)

greet("the person who is reading this repository:)")
# Out:
# Hello, the person who is reading this repository:)

# %% [markdown]
# The code above is the code that i got from Colilot.
#
# The code works because the it uses valid Python syntax to assign values to variables, perform arithmetic operations with built-in operators, and define a function before calling it. The first part calculates and prints the sum, difference, product, and division of two integers, while the second part defines a greet function that takes a name as input and prints a greeting message. Since all operations are compatible with the data types provided and the function is called correctly, Python executes the code without errors.

# %% [markdown]
# ### Running Some Prompts in Microsoft Copilot

# %% [markdown]
# #### 1. Variables

# %%
# Store a message in a variable
greeting = "Hello, world!"

# Print the message using the variable
print(greeting)
# Out:
# Hello, world!

# %% [markdown]
# **Step-By-Step**
#
# greeting = "Hello, world!"
#   - The coding above is a variable named 'greeting'.
#   - A variable is like a labelled box where you can store information.
#   - In this example, the information is the text "Hello, world!". In Python it is called 'string'.
#
# print(greeting)
#   - Instead of printing the text directly, it print the value stored in the variable.
#   - This shows that variables can hold data and be reused anywhere in the program.
#
# **Key Aspects**
#  - It makes it able to chnage the message by updating the variable without modifying the 'print ()' satement, which makess the code flexible.
#  - Text data must be enclosed in quotes (" " or ' ')

# %% [markdown]
# #### 2. Functions

# %%
# Define a function that prints a greeting
def say_hello():
    print("Hello, world!")

# Call the function to run it
say_hello()
# Out:
# Hello, world!

# %% [markdown]
# **Step-By-Step**
#
# def say_hello():
#  - In Python 'def' is a special keyword that means define a function.
#  - 'say_hello' is the name of the function. You can choose any name, but it should describe what the function does.
#  - '()' means this function does not take any input yet.
#  - ':' tells Python that the next indented lines belong to this function.
#
# print("Hello, world!")
#  - This line is indented (spaces at the start) because it is inside the function.
#  - It tells Python what the function should do → print "Hello, world!".
#
# say_hello()
#  - Writing the function name followed by () runs the function.
#  - If you do not call the function, nothing happens because defining a function only stores it for later use.
#
#
#
# **Key Aspects**
#
# Functions in Python are essential because they allow you to organise code into reusable blocks, making programs easier to read, maintain, and debug. A function is defined using the 'def' keyword followed by a name and parentheses, and its body must be indented to show which statements belong to it. Defining a function does not execute it, you must call the function by writing its name followed by parentheses. This separation between definition and execution is important because it lets you reuse the same logic multiple times without rewriting the code. Moreover, functions make programs more flexible, as they can later accept inputs and return outputs, enabling dynamic behaviour.

# %% [markdown]
# #### 3. Other Initial prompts to explore

# %% [markdown]
# ##### **Initial prompt to understand loops (1)**

# %%
# Print "Hello, world!" 5 times using a loop
for i in range(4):
    print("Hello, world!")
# Out:
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!

# %% [markdown]
# **Step-By-Step**
#
# for i in range(4):
#  - This is the start for the loop in Python.
#  - 'i' is a loop variable that changes each time the loop runs.
#  - 'range(4)' creates a sequence of numbers: 0, 1, 2, 3, 4.
#  - The loop will run 4 times, once for each number in that sequence.
#  - ':' tells Python that the next indented lines belong to the loop.
#
# print("Hello, world!")
#  - This line is indented, so it runs every time the loop repeats.
#  - Since the loop runs 4 times, "Hello, world!" will be printed 4 times.
#
#
# **Key Aspects**
#
# Loops repeat code automatically without writing it multiple times. Everything inside the loop must be indented. Moreover, 'range(#)' controls how many times the loop runs. The loop variable (i) can be used if you want to show the count.

# %% [markdown]
# ##### **Initial prompt to understand data structures such as lists (2)**

# %%
# Step 1: Create a list of greetings
greetings = ["Hello, world!", "Hi readers!", "Welcome to my repository (=^･ω･^=)", "Please enjoy (*ˊᗜˋ)ﾉﾞ","Good day!"]

# Step 2: Use a loop to print each greeting
for message in greetings:
    print(message)
# Out:
# Hello, world!
# Hi readers!
# Welcome to my repository (=^･ω･^=)
# Please enjoy (*ˊᗜˋ)ﾉﾞ
# Good day!

# %% [markdown]
# **Step-By-Step**
#
# greetings = ["Hello, world!", "Hi readers!", "Welcome to my repository (=^･ω･^=)", "Please enjoy (*ˊᗜˋ)ﾉﾞ","Good day!"]
#  - A list is a collection of items stored in one variable.
#  - Lists are written inside square brackets '[ ]'.
#  - Items are separated by commas ','.
#  - In this example, greetings contains 5 different text messages.
#
#
# for message in greetings:
#     print(message)
#  - 'for message in greetings' means take each item from the list one by one and store it in message.
#  - 'print(message)' prints the current greeting.
#  - The loop runs as many times as there are items in the list. For this will be 5 times.
#
# **Key Aspects**
#
# A list in Python allows for storing multiple values in a single variable, making it easier to manage related data together. It will be able to access individual items using their position or loop through the entire list to process each item. Lists are flexible because it is easy to add, remove, or modify elements, which helps keep code organised and efficient.

# %% [markdown]
# ##### **Initial prompt to understand data structures such as dictionaries (3)**

# %%
# Step 1: Create a dictionary of greetings in different languages
greetings = {
    "English": "Hello, world! ʚ❤︎ɞ",
    "Spanish": "¡Hola, mundo! ʚ❤︎ɞ",
    "French": "Bonjour, le monde! ʚ❤︎ɞ",
    "Japanese": "こんにちは, 世界! ʚ❤︎ɞ"
}

# Step 2: Loop through the dictionary and print each greeting
for language, message in greetings.items():
    print(f"{language}: {message}")
# Out:
# English: Hello, world! ʚ❤︎ɞ
# Spanish: ¡Hola, mundo! ʚ❤︎ɞ
# French: Bonjour, le monde! ʚ❤︎ɞ
# Japanese: こんにちは, 世界! ʚ❤︎ɞ

# %% [markdown]
# **Step-By-Step**
#
# greetings = {
#     "English": "Hello, world! ʚ❤︎ɞ",
#     "Spanish": "¡Hola, mundo! ʚ❤︎ɞ",
#     "French": "Bonjour, le monde! ʚ❤︎ɞ",
#     "Japanese": "こんにちは, 世界! ʚ❤︎ɞ"
#  - A dictionary stores data in key-value pairs. Keys (like "English", "Japanese") act like labels. Values (like "Hello, world! ʚ❤︎ɞ", "こんにちは, 世界! ʚ❤︎ɞ") are the data associated with those keys.
#  - Dictionaries use curly braces '{ }' and separate keys and values with a colon ':'.
#
#
# for language, message in greetings.items():
#     print(f"{language}: {message}")
#  - '.items()' gives both the key and value for each pair in the dictionary.
#  - language stores the key (e.g., "English"), and message stores the value (e.g., "Hello, world! ʚ❤︎ɞ").
#  - 'print(f"{language}: {message}")' uses an f-string to format the output nicely.
#
# **Key Aspects**
#
# Dictionaries store data as key-value pairs, allowing you to easily look up values by their keys. You can loop through keys and values using '.items()'. They are useful for organising data with clear labels and corresponding values.

# %% [markdown]
# ##### **Initial prompt to understand data structures such as arrays (4)**

# %%
import array

# Step 1: Create an array of numbers (representing positions for greetings)
positions = array.array('i', [1, 2, 3, 4, 5])

# Step 2: Loop through the array and print "Hello, world!" with each position
for pos in positions:
    print(f"{pos}. Hello, world ₍ᐢ..ᐢ₎ ")
# Out:
# 1. Hello, world ₍ᐢ..ᐢ₎
# 2. Hello, world ₍ᐢ..ᐢ₎
# 3. Hello, world ₍ᐢ..ᐢ₎
# 4. Hello, world ₍ᐢ..ᐢ₎
# 5. Hello, world ₍ᐢ..ᐢ₎

# %% [markdown]
# **Step-By-Step**
#
# import array
#  - Python’s array module provides an array data structure similar to arrays in languages like C or Java.
#  - Arrays store elements of the same type.
#
# positions = array.array('i', [1, 2, 3, 4, 5])
#  - 'array.array('i', [...])' creates an array of integers.
#  - 'i' is the type code for integers. Moreover, [1, 2, 3, 4, 5] is the initial data stored in the array.
#
#
# for pos in positions:
#     print(f"{pos}. Hello, world!")
#  - The loop goes through each number in the array.
#  - 'f"{pos}. Hello, world!"' uses an f-string to print the position with the greeting.
#
# **Key Aspects**
#
# Arrays in Python are type-specific. They are more memory-efficient than lists for large numeric data. Use the array module for arrays, lists are more common for general use. Arrays are great for numeric operations where consistency of type matters.

# %% [markdown]
# ##### **Initial prompt to understand how to import libraries that extend functionality(5)**

# %%
# Step 1: Import a library (random) to extend functionality
import random

# Step 2: Create a list of greetings
greetings = ["Hello, world!", "Hi there!", "Welcome!", "Good day!", "(ᐡ • ˕ • ᐡ)", "ʕ•ﻌ•ʔ♡"]

# Step 3: Use the library to pick a random greeting
print(random.choice(greetings))
# Out:
# (ᐡ • ˕ • ᐡ)

# %% [markdown]
# **Step-By-Step**
#
# import random
#  - 'import' is a Python keyword used to bring in libraries, which is the collections of pre-written code.
#  - In this example, we import the random library, which helps us generate random numbers or choose random items.
#
# greetings = ["Hello, world!", "Hi there!", "Welcome!", "Good day!", "(ᐡ • ˕ • ᐡ)", "ʕ•ﻌ•ʔ♡"]
#  - We store multiple greetings in a list so we can randomly select one.
#
#
# print(random.choice(greetings))
#  - 'random.choice(greetings)' picks one random item from the list.
#  - 'print()' displays that greeting.
#
# **Key Aspects**
#
# Libraries extend Python’s functionality without writing everything from scratch. After importing, you can use the library’s functions.

# %% [markdown]
# ##### **Initial prompt to understand how to use conditional if, else, elif statements (6)**

# %%
# Step 1: Ask the user for their favorite number
number = int(input("Enter your favorite number: "))

# Step 2: Use if, elif, and else to respond
if number > 10:
    print("Hello, world! That's a big number!")
elif number == 10:
    print("Hello, world! That's exactly ten!")
else:
    print("Hello, world! That's a small number!")
# Out:
# Hello, world! That's a small number!

# %% [markdown]
# **Step-By-Step**
#
# number = int(input("Enter your favorite number: "))
#  - 'input()' asks the user to type something.
#  - 'int()' converts the input from text to an integer.
#  - The number is stored in the variable number.
#
#
# if number > 10:
#     print("Hello, world! That's a big number!")
#  - If the first condition was false, this checks if the number equals 10.
#
#
# else:
#     print("Hello, world! That's a small number!")
#  - 'else' runs if none of the above are true
#
#
# **Key Aspects**
#
# 'if', 'elif', 'else' let you make decisions in your code. Conditions use comparison operators like '>', '<', '=='. Moreover, Indentation matters. All code inside each block must be indented. Only one block runs based on the first true condition.a

# %% [markdown]
# ##### **Initial prompt to understand how to use operators in Python (7)**

# %%
# Step 1: Basic arithmetic operators with numbers
a = 1998
b = 2003
print("Addition:", a + b)       # Adds two numbers
print("Multiplication:", a * b) # Multiplies two numbers

# Step 2: Operators with strings
text = "Hello, world! "
print("String addition:", text + "It's 4 in the morning")  # Combines two strings
print("String multiplication:", text * 3)         # Repeats the string 3 times
# Out:
# Addition: 4001
# Multiplication: 4001994
# String addition: Hello, world! It's 4 in the morning
# String multiplication: Hello, world! Hello, world! Hello, world!

# %% [markdown]
# **Step-By-Step**
# a = 1998
# b = 2003
# print("Addition:", a + b)
# print("Multiplication:", a * b)
#  - '+' adds two numbers (ex: 5 + 3 = 8).
#  - '*' multiplies two numbers (ex: 5 × 3 = 15).
#  - These are basic arithmetic operators.
#
# text = "Hello, world! "
# print("String addition:", text + "It's 4 in the morning")
# print("String multiplication:", text * 3)
#  - '+' with strings concatenates (joins) them
#    - "Hello, world!" + "It's 4 in the morning" → "Hello, world! It's 4 in the morning".
#  - '*' with a string and a number repeats the string
#    - "Hello, world! " * 3 → "Hello, world! Hello, world! Hello, world! ".
#
# **Key Aspects**
#
# The same operator can behave differently depending on the data type
#  - Numbers → '+' adds, '*' multiplies.
#  - Strings → '+' joins, '*' repeats.
# Python is type-sensitive. You cannot mix numbers and strings directly (e.g., "Hello" + 5 will cause an error). To combine text and numbers, you must convert numbers to strings using 'str()'. such as 'print("Number is: " + str(a))'

# %% [markdown]
# ##### **Initial prompt to understand how to use advanced concepts such as classes, objects, and methods (8)**

# %%
# Step 1: Define a class
class Greeter:
    # Step 2: Define a method inside the class
    def say_hello(self):
        print("Hello, world! ٩(ˊᗜˋ*)و")

# Step 3: Create an object (instance of the class)
greet = Greeter()

# Step 4: Call the method using the object
greet.say_hello()
# Out:
# Hello, world! ٩(ˊᗜˋ*)و

# %% [markdown]
# **Step-By-Step**
#
# class Greeter:
#  - Define a Class
#  - class is a keyword used to create a class.
#  - A class is like a blueprint for creating objects.
#  - Here, Greeter is the name of the class.
#
#
# def say_hello(self):
#     print("Hello, world!")
#  - Define a Method
#  - A method is a function inside a class.
#  - 'Self' refers to the object that calls the method (it’s required in class methods).
#  - This method prints "Hello, world!".
#
#
# greet = Greeter()
#  - An object (or instance) is created from the class.
#  - 'Greeter()' calls the class to make a new object named greet.
#
# greet.say_hello()
#  - The object is used to 'greet' call the method 'say_hello()'.
#  - This runs the code inside the method and prints "Hello, world!".
#
# **Key Aspects**
#
# lass = blueprint
# Object = actual thing created from the blueprint
# Methods define what the object can do.
# self is always the first parameter in methods to refer to the object.
# You must create an object before calling its methods.

# %% [markdown]
# ##### **Initial prompt to learn more about basic Python syntax (9)**

# %%
# This is a comment

# %% [markdown]
#  1. Comments
#   - Comments start with '#' and are ignored by Python.
#   - Use comments to explain your code.
#
# Keep comments clear and concise.

# %%
greeting = "Hello, world!"

# %% [markdown]
# 2. Variables
#  - Variables store data.
#  - No need to declare type explicitly (Python is dynamically typed).
#
# Use lowercase names with underscores for readability (e.g., my_variable).

# %%
print(greeting)
# Out:
# Hello, world!

# %% [markdown]
# 3. Printing
#  - print() displays output.
#  - You can print text, numbers, or variables.

# %%
if True:
    print("Indented correctly!")
# Out:
# Indented correctly!

# %% [markdown]
# 4. Indentation
#  - Python uses indentation (spaces) instead of braces '{}'.

# %%
number = 5
if number > 10:
    print("Big number")
elif number == 10:
    print("Exactly ten")
else:
    print("Small number")
# Out:
# Small number

# %% [markdown]
# 5. Conditionals
#  - 'if', 'elif', and 'else' control decisions.
#  - Conditions use operators like '>', '<', '=='.

# %%
for i in range(3):
    print("Hello, world!")
# Out:
# Hello, world!
# Hello, world!
# Hello, world!

# %% [markdown]
# 6. Loops
#  - for loops repeat code.
#  - range(3) runs 3 times.
#
# Keep loop variables short but meaningful.

# %%
def say_hello():
    print("Hello, world!")

say_hello()
# Out:
# Hello, world!

# %% [markdown]
# 7. Functions
#  - Functions group reusable code.
#  - Defined with def, called by name.
#
# Function names should be lowercase with underscores.

# %%
class Greeter:
    def say_hello(self):
        print("Hello, world!")

greet = Greeter()
greet.say_hello()
# Out:
# Hello, world!

# %% [markdown]
# 8. Classes and Objects
#  - class defines a blueprint.
#  - object is an instance of a class.
#  - Methods are functions inside classes.

# %% [markdown]
# Rossum, G., Warsaw, B., and Coghlan, A. (2013). PEP 8 – Style Guide for Python Code. Python Enhancement Proposals Python. Retrieved from: https://peps.python.org/pep-0008/

# %% [markdown]
# ##### **Initial prompt to learn more about best practice in Python to promote principles of simplicity, security and inclusion (10)**

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# 1. Simplicity
#
# The principle of simplicity means writing code that is clear, minimal, and easy to understand.
# The code has a single responsibility, it only prints text to the console. It has minimal dependencies because it requires no imports or extra logic. Its readability is high, as anyone familiar with Python can understand it instantly. This matters because simple code reduces cognitive load and makes maintenance easier.

# %%
import html
import sys

def safe_print(message: str) -> None:
    """
    Prints a sanitized message to prevent injection attacks.
    """
    if not isinstance(message, str):
        raise TypeError("Message must be a string.")
    
    # Limit message length to avoid abuse
    if len(message) > 100:
        raise ValueError("Message too long.")
    
    # Escape HTML special characters
    sanitized = html.escape(message)
    print(sanitized)

if __name__ == "__main__":
    # Default message if no argument provided
    user_input = "Hello, World!"
    safe_print(user_input)
# Out:
# Hello, World!

# %% [markdown]
# 2. Security
#
# The code performs input validation by checking both the type and the length of the input. It also sanitises the input using HTML.escape() to neutralise any HTML or script tags. It applies fail-safe defaults by printing “Hello, World!” when no input is provided. This is important because it helps prevent injection attacks and resource abuse.

# %%
import locale

def hello_world():
    # Detect system locale
    lang = locale.getdefaultlocale()[0] or "en"
    
    greetings = {
        "en": "Hello, World!",
        "es": "¡Hola, Mundo!",
        "fr": "Bonjour, le monde!",
        "ja": "こんにちは、世界！"
    }
    
    # Fallback to English if language not supported
    message = greetings.get(lang[:2], greetings["en"])
    
    print(message)

if __name__ == "__main__":
    hello_world()
# Out:
# Hello, World!
# /tmp/ipykernel_2696/59469369.py:5: DeprecationWarning: 'locale.getdefaultlocale' is deprecated and slated for removal in Python 3.15. Use setlocale(), getencoding() and getlocale() instead.
#   lang = locale.getdefaultlocale()[0] or "en"

# %% [markdown]
# 3. Inclusion
#
# The code performs language detection by using the system locale to personalise output. It includes a fallback mechanism that defaults to English if the detected locale isn’t supported. This approach matters because it makes the software accessible to a global audience.

# %% [markdown]
# ### Try the Code in Codespace

# %% [markdown]
# This section will be my learning process using GitHub Copilot to explore Python programming concepts.

# %% [markdown]
# **Initial Prompt — Functions**
#
# -Prompt I submitted to Copilot
# "Could you suggest a modification of the Python code for “Hello, world!” to demonstrate the concept of functions to a complete beginner in programming? Please explain the code step-by-step, highlighting any key aspects."
#
# -Purpose
# This section explores the programming concept: Functions

# %%
def say_hello():
    """
    This function prints 'Hello, World!' to the screen.
    """
    print("Hello, World!")

# Call the function
say_hello()
# Out:
# Hello, World!

# %% [markdown]
# It worked.
#
# Friends code also worked well.
#
# Suggested Prompts + Additional Prompts
# - Functions with Arguments
#
# Here I tested the extra prompts suggested by Copilot and my own questions.

# %%
def say_hello(name):
    """
    This function prints a personalized greeting.
    :param name: The name of the person to greet.
    """
    print(f"Hello, {name}!")

# Call the function with an example name
say_hello("Alice")
# Out:
# Hello, Alice!

# %% [markdown]
# **Summary of Learning Outcomes**
#
# I learned how to use GitHub Copilot to explore different Python concepts. I gained an understanding of functions, variables, dictionaries, and loops by studying various examples. When errors occurred, I practiced debugging with Copilot’s step-by-step explanations. Comparing outputs with my peers helped me see alternative ways to approach each concept. Overall, experimenting with different prompts improved my ability to read and understand Python code.

# %% [markdown]
# ### Exploring Other Prompts and Concepts

# %% [markdown]
# Initial Prompt typed in Copilot:
#
# “Could you suggest a modification of the Python code for ‘Hello, world!’ to demonstrate the concept of functions?”

# %%
def say_hello():
    """
    This function prints 'Hello, World!' to the screen.
    """
    print("Hello, World!")

# Call the function
say_hello()
# Out:
# Hello, World!

# %%
def get_message():
    """
    Returns the message to be printed.
    """
    return "Hello, World!"

def display_message(message):
    """
    Prints the given message.
    """
    print(message)

def main():
    """
    Main function that controls the flow.
    """
    message = get_message()  # Call function to get the message
    display_message(message) # Call function to display the message

# Run the program
if __name__ == "__main__":
    main()
# Out:
# Hello, World!

# %% [markdown]
# **Why This Is Different**
#
# Instead of using just one simple function, the examples demonstrate multiple functions working together. They show how return values, arguments, and overall program structure operate. This helps prepare beginners for understanding modular programming.
#
# **Findings**
#
# Re-running the same prompt showed me different ways to express the same concept. It helped me see that Python ideas can be explained and coded in multiple valid ways.

# %% [markdown]
# ## More on Algorithms, Pseudocodes, Codes

# %% [markdown]
# ### Working with Algorithms

# %% [markdown]
# The sentences below will be a poem to give an example of algorithms
#
# **How Do I Love Thee?**
#
# How do I love thee? Let me count the ways.
#
# I love thee to the depth and breadth and height
#
# My soul can reach, when feeling out of sight
#
# For the ends of being and ideal grace.
#
# I love thee to the level of every day’s
#
# Most quiet need, by sun and candle-light.
#
# I love thee freely, as men strive for right.
#
# I love thee purely, as they turn from praise.
#
# I love thee with the passion put to use
#
# In my old griefs, and with my childhood’s faith.
#
# I love thee with a love I seemed to lose
#
# With my lost saints. I love thee with the breath,
#
# Smiles, tears, of all my life; and, if God choose,
#
# I shall but love thee better after death.

# %%
def group_words_by_frequency(sentence):
    """
    Groups words in a sentence and sorts them by frequency (highest first).
    :param sentence: A string containing the sentence.
    :return: A list of tuples (word, count) sorted by count descending.
    """
    # Step 1: Normalize the sentence (lowercase)
    sentence = sentence.lower()
    
    # Step 2: Split into words
    words = sentence.split()
    
    # Step 3: Count occurrences
    word_count = {}
    for word in words:
        word_count[word] = word_count.get(word, 0) + 1
    
    # Step 4: Sort by frequency (descending)
    sorted_by_freq = sorted(word_count.items(), key=lambda x: x[1], reverse=True)
    
    return sorted_by_freq

# Example usage
sentence = "How do I love thee? Let me count the ways. I love thee to the depth and breadth and height My soul can reach, when feeling out of sight For the ends of being and ideal grace. I love thee to the level of every day’s Most quiet need, by sun and candle-light. I love thee freely, as men strive for right. I love thee purely, as they turn from praise. I love thee with the passion put to use In my old griefs, and with my childhood’s faith. I love thee with a love I seemed to lose With my lost saints. I love thee with the breath, Smiles, tears, of all my life; and, if God choose, I shall but love thee better after death."
result = group_words_by_frequency(sentence)
print(result)
# Out:
# [('i', 10), ('love', 10), ('thee', 8), ('the', 6), ('and', 5), ('my', 5), ('with', 5), ('to', 4), ('of', 4), ('for', 2), ('as', 2), ('how', 1), ('do', 1), ('thee?', 1), ('let', 1), ('me', 1), ('count', 1), ('ways.', 1), ('depth', 1), ('breadth', 1), ('height', 1), ('soul', 1), ('can', 1), ('reach,', 1), ('when', 1), ('feeling', 1), ('out', 1), ('sight', 1), ('ends', 1), ('being', 1), ('ideal', 1), ('grace.', 1), ('level', 1), ('every', 1), ('day’s', 1), ('most', 1), ('quiet', 1), ('need,', 1), ('by', 1), ('sun', 1), ('candle-light.', 1), ('freely,', 1), ('men', 1), ('strive', 1), ('right.', 1), ('purely,', 1), ('they', 1), ('turn', 1), ('from', 1), ('praise.', 1), ('passion', 1), ('put', 1), ('use', 1), ('in', 1), ('old', 1), ('griefs,', 1), ('childhood’s', 1), ('faith.', 1), ('a', 1), ('seemed', 1), ('lose', 1), ('lost', 1), ('saints.', 1), ('breath,', 1), ('smiles,', 1), ('tears,', 1), ('all', 1), ('life;', 1), ('and,', 1), ('if', 1), ('god', 1), ('choose,', 1), ('shall', 1), ('but
# ...

# %% [markdown]
# The code above was generated by Copilot to count how many times each word appears in a set of sentences. I also wanted the results to be displayed in order, from the most frequent words to the least frequent ones. I have used a poem to generate algorithm.

# %% [markdown]
# Here are some algorithms I use in daily life:
#
# 1. **Making Coffee in the morning**
#    - Boil water.
#    - Add instant coffee in the mug.
#    - Add honey in the mug.
#    - Add hot water in the mug.
#    - Mix really well.
#    - Add milk in the mug as well.
#    - Mix it.
#    - Drink it.
#
# 2. **Getting Ready for School**
#    - Wake up.
#    - Brush teeth.
#    - Brush my hair.
#    - Put make up.
#    - Get dressed.
#    - Pack bag.
#    - Leave for school.
#
#
# It helps you understand that algorithms are simply step-by-step instructions, not just pieces of code. Writing them in Markdown makes your notebook more organised and easier to read.

# %% [markdown]
# ### Pseudocode

# %% [markdown]
# **Pseudocode Version**
#
# INPUT: Ingredients (instant coffee, honey, milk), water
#
# STEP 1: Boil water
#
# STEP 2: Put instant coffee into mug
#
# STEP 3: Add honey into mug
#
# STEP 4: Pour hot water into mug
#
# STEP 5: Mix contents thoroughly
#
# STEP 6: Add milk into mug
#
# STEP 7: Mix again
#
# STEP 8: Drink coffee
#
# OUTPUT: A cup of coffee ready to drink

# %% [markdown]
# **Optional Advanced Pseudocode**
#
# START
#
# SET water = cold
#
# BOIL water
#
# ADD coffee to mug
#
# ADD honey to mug
#
# POUR hot water into mug
#
# MIX contents
#
# ADD milk to mug
#
# MIX contents again
#
# OUTPUT "Coffee is ready"
#
# END

# %% [markdown]
# For this task, I took a simple everyday routine and converted it into pseudocode.
#
# - an algorithm → a natural-language description of steps
# - pseudocode → a more structured, programming-style representation
#
# Writing pseudocode helps organise actions clearly and logically, even though it is not real Python code. It also uses concepts similar to those seen when exploring Python, such as variables, conditionals (IF/ELSE), and step-by-step operations.

# %% [markdown]
# ### Code

# %% [markdown]
# **Sonnet 18: Shall I compare thee to a summer’s day?**
#
# **By William Shakespeare**
#
# Shall I compare thee to a summer’s day?
#
# Thou art more lovely and more temperate:
#
# Rough winds do shake the darling buds of May,
#
# And summer’s lease hath all too short a date;
#
# Sometime too hot the eye of heaven shines,
#
# And often is his gold complexion dimm'd;
#
# And every fair from fair sometime declines,
#
# By chance or nature’s changing course untrimm'd;
#
# But thy eternal summer shall not fade,
#
# Nor lose possession of that fair thou ow’st;
#
# Nor shall death brag thou wander’st in his shade,
#
# When in eternal lines to time thou grow’st:
#
#    So long as men can breathe or eyes can see,
#
#    So long lives this, and this gives life to thee.

# %%
def group_words_by_frequency(sentence):
    """
    Groups words in a sentence and sorts them by frequency (highest first).
    :param sentence: A string containing the sentence.
    :return: A list of tuples (word, count) sorted by count descending.
    """
    # Step 1: Normalize the sentence (lowercase)
    sentence = sentence.lower()
    
    # Step 2: Split into words
    words = sentence.split()
    
    # Step 3: Count occurrences
    word_count = {}
    for word in words:
        word_count[word] = word_count.get(word, 0) + 1
    
    # Step 4: Sort by frequency (descending)
    sorted_by_freq = sorted(word_count.items(), key=lambda x: x[1], reverse=True)
    
    return sorted_by_freq

# Example usage
sentence = "Shall I compare thee to a summer’s day? Thou art more lovely and more temperate: Rough winds do shake the darling buds of May, And summer’s lease hath all too short a date; Sometime too hot the eye of heaven shines, And often is his gold complexion dimm'd; And every fair from fair sometime declines, By chance or nature’s changing course untrimm'd; But thy eternal summer shall not fade, Nor lose possession of that fair thou ow’st; Nor shall death brag thou wander’st in his shade, When in eternal lines to time thou grow’st: So long as men can breathe or eyes can see, So long lives this, and this gives life to thee."
result = group_words_by_frequency(sentence)
print(result)
# Out:
# [('and', 5), ('thou', 4), ('shall', 3), ('to', 3), ('of', 3), ('fair', 3), ('a', 2), ('summer’s', 2), ('more', 2), ('the', 2), ('too', 2), ('sometime', 2), ('his', 2), ('or', 2), ('eternal', 2), ('nor', 2), ('in', 2), ('so', 2), ('long', 2), ('can', 2), ('i', 1), ('compare', 1), ('thee', 1), ('day?', 1), ('art', 1), ('lovely', 1), ('temperate:', 1), ('rough', 1), ('winds', 1), ('do', 1), ('shake', 1), ('darling', 1), ('buds', 1), ('may,', 1), ('lease', 1), ('hath', 1), ('all', 1), ('short', 1), ('date;', 1), ('hot', 1), ('eye', 1), ('heaven', 1), ('shines,', 1), ('often', 1), ('is', 1), ('gold', 1), ('complexion', 1), ("dimm'd;", 1), ('every', 1), ('from', 1), ('declines,', 1), ('by', 1), ('chance', 1), ('nature’s', 1), ('changing', 1), ('course', 1), ("untrimm'd;", 1), ('but', 1), ('thy', 1), ('summer', 1), ('not', 1), ('fade,', 1), ('lose', 1), ('possession', 1), ('that', 1), ('ow’st;', 1), ('death', 1), ('brag', 1), ('wander’st', 1), ('shade,', 1), ('when', 1), ('lines', 1), ('tim
# ...

# %% [markdown]
# The code above was generated by Copilot to count how many times each word appears in a set of sentences. I also wanted the results to be displayed in order, from the most frequent words to the least frequent ones.

# %%
def make_coffee():
    """
    Simulates making coffee step by step.
    """
    water = "cold"
    print("Step 1: Boil water...")
    water = "hot"
    
    print("Step 2: Add instant coffee to mug.")
    print("Step 3: Add honey to mug.")
    print("Step 4: Pour hot water into mug.")
    print("Step 5: Mix contents thoroughly.")
    print("Step 6: Add milk to mug.")
    print("Step 7: Mix contents again.")
    
    return "Coffee is ready!"

# 実行
result = make_coffee()
print(result)
# Out:
# Step 1: Boil water...
# Step 2: Add instant coffee to mug.
# Step 3: Add honey to mug.
# Step 4: Pour hot water into mug.
# Step 5: Mix contents thoroughly.
# Step 6: Add milk to mug.
# Step 7: Mix contents again.
# Coffee is ready!

# %% [markdown]
# The code above is the code that Copilot generated. It works showing step by step process.

# %% [markdown]
# ### Python libraries
#
# It are collections of pre-written code that provide useful tools for completing specific tasks. They allow developers to avoid rewriting common functions from scratch by offering reusable modules. Examples include numpy and pandas for data analysis, scikit-learn and tensorflow for machine learning, flask and django for web development, and matplotlib and seaborn for creating visualizations.
#
# Most libraries are available on the Python Package Index (PyPI) and can be installed easily using package managers like pip. Libraries make Python more powerful and save time when building programs.

# %%
import numpy
import pandas
print("Libraries installed successfully!")
# Out:
# Libraries installed successfully!

# %% [markdown]
# ### Importing the libraries and packages

# %%
from IPython.display import Video

# %% [markdown]
# 1st attempt

# %%
from IPython.display import YouTubeVideo

YouTubeVideo("7KIHvuMl4Kk")

# %% [markdown]
# 2nd attempt

# %%
from IPython.display import YouTubeVideo

# Display a YouTube video by its ID
YouTubeVideo("7KIHvuMl4Kk", width=640, height=360)

# %% [markdown]
# 1st and 2nd attempt have worked.
# In the same time, Codespaces does not allow external iframe content for security reasons. Both IPython.display.YouTubeVideo() try to embed content from outside the Codespace. This means that even if the code is written correctly, the video will not display in the preview.

# %% [markdown]
# I tried to add a video (.mp4), but during the process it almost caused issues with my entire Codespace and repository. It took me nearly 30 minutes to fix everything, so I decided not to include any videos.

# %% [markdown]
# ### Understanding a Program: Parsing and Reading

# %%
import webbrowser
import requests

print("Shall we hunt down an old website?")
site = input("Type a website URL: ")
era = input("Type year, month, and date, e.g., 20150613: ")
url = "http://archive.org/wayback/available?url=%s&timestamp=%s" 
(site, era)
response = requests.get(url)
data = response.json()

try:
   old_site = data["archived_snapshots"]["closest"]["url"]
   print("Found this copy: ", old_site)
   print("It should appear in your browser.")
   webbrowser.open(old_site)

except:
 print("Sorry, could not find the site.")
# Out:
# Shall we hunt down an old website?
# Sorry, could not find the site.

# %% [markdown]
# 1. How many libraries were imported?
# Two libraries:
# - webbrowser
# - requests
#
#
# 2. How many variables were used?
# Six variables are assigned values in the code:
# - site — the website URL input by the user
# - era — the date (YYYYMMDD) input by the user
# - url — the API request URL constructed using site and era
# - response — the HTTP response from the Wayback API
# - data — the parsed JSON from the response
# - old_site — the URL of the closest archived snapshot (inside try)
#
# 3. How many strings appear in the program?
# 10 string literals appear:
# - "Shall we hunt down an old website?"
# - "Type a website URL: "
# - "Type year, month, and date, e.g., 20150613: "
# - "http://archive.org/wayback/available?url=%s&amp;timestamp=%s"
# - "archived_snapshots"
# - "closest"
# - "url"
# - "Found this copy: "
# - "It should appear in your browser."
# - "Sorry, could not find the site."
#
# 4. How many times is something printed? What was printed?
# There are 4 print() statements in the code.
# - print("Shall we hunt down an old website?")
# - print("Found this copy: ", old_site)  → prints the message and the snapshot URL
# - print("It should appear in your browser.")
# - print("Sorry, could not find the site.")

# %% [markdown]
# This task helps me practice reading and understanding a Python program. It is important to be able to recognise basic parts such as imported libraries, variables, strings, and print statements. By counting and identifying these elements, I learn how a real program is structured. This exercise improves my ability to analyse code and prepares me for working with more complex programs in the future.

# %% [markdown]
# ### Text Processing Example: Word Frequency Counting

# %%
from collections import Counter
import re

def process_text(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        text = f.read().lower()

    # Remove punctuation and split into words
    words = re.findall(r'\w+', text)
    word_counts = Counter(words)

    for word, count in word_counts.most_common(10):
        print(f"{word}: {count}")

process_text("some_text.txt")
# Out:
# i: 11
# love: 11
# thee: 10
# the: 6
# and: 6
# my: 5
# with: 5
# to: 4
# of: 4
# how: 2

# %% [markdown]
# This exercise is important because it teaches how to work with real-world data in Python. By reading a text file, cleaning it, and counting word frequencies, I practice using files, functions, variables, and loops. It also introduces basic data processing, which is a first step toward natural language processing and machine learning. Finally, it helps me learn how to manage files and debug code in Codespaces, which are essential skills for programming projects.

# %% [markdown]
# ### Image Processing Example: Grayscale Conversion and Basic Feature Extraction

# %%
from PIL import Image
import numpy as np

def process_image(file_path):
    # Open the image and convert to grayscale
    img = Image.open(file_path).convert("L")
    
    # Convert image to NumPy array
    img_array = np.array(img)
    
    # Calculate average pixel intensity
    avg_intensity = np.mean(img_array)
    print(f"Average intensity: {avg_intensity}")
    
    # Save the processed grayscale image
    img.save("processed_image.png")

process_image("sample_image.jpg")
# Out:
# Average intensity: 107.6797981003399

# %% [markdown]
# ### Audio Processing Example: Waveform and Frequency Analysis

# %%
import librosa
import numpy as np

def process_audio(file_path):
    # Load audio at a default sample rate
    y, sr = librosa.load(file_path, sr=None)

    # Compute average amplitude (a rough measure of volume)
    avg_amplitude = np.mean(np.abs(y))
    print(f"Average amplitude: {avg_amplitude}")

    # Compute a short-time Fourier transform (STFT) for frequency analysis
    D = np.abs(librosa.stft(y))
    freq_bins = np.mean(D, axis=1)
    dominant_frequency_bin = np.argmax(freq_bins)
    print(f"Dominant frequency bin: {dominant_frequency_bin}")

# Call the function
process_audio("sample_audio.wav")

# %% [markdown]
# This exercise teaches how to work with audio as data in Python. Audio files are represented as numeric arrays over time, similar to how images are arrays of pixels or text is a sequence of words. Calculating the average amplitude yields a simple measure of volume. By performing a Fourier transform, we can analyse which frequencies are most prominent.
#
# However, because the audio file is too big, it does not allow me to play or incorporate it.

# %% [markdown]
# ### Using IPython.display to display images and audio

# %%
from IPython.display import Image 

Image("picture1.jpg")
